# %%
#Imprimir una linea "Esto es una función print"
print("Esto es una función print")
# Out:
# Esto es una función print

# %% [markdown]
# guardar un "int" e imprimirlo en pantalla

# %%
myint = 20
print(myint)
# Out:
# 20

# %% [markdown]
# #guardar un "Float" e imprime por pantalla

# %%
myfloat= 20.5
print(myfloat)
# Out:
# 20.5

# %% [markdown]
# guardar un string e imprime por pantalla

# %%
mystring = 'hola que tal'
print(mystring)
# Out:
# hola que tal

# %% [markdown]
# Guardar 2 numeros, sumarlos e imprimirlos por pantalla

# %%
one = 52
two = 15.5
suma = one + two
print(suma)
# Out:
# 67.5

# %% [markdown]
# Guardar 2 strings con un espacio en el medio

# %%
hello = "Hola"
separacion = " "
good = "buenos"
separacion2 = " "
morning = "dias"
print(hello, separacion, good, separacion2, morning)
# Out:
# Hola   buenos   dias

# %% [markdown]
# Comprobar como se asigna dos valores a la vez

# %%
a, b = 24, 30
print(a, b)
# Out:
# 24 30

# %% [markdown]
# #Listas

# %%
#Guarda una lista e imprime por pantalla
mylist = [1, 2, 4, "pepe", "mundo"]
print(mylist)
# Out:
# [1, 2, 4, 'pepe', 'mundo']

# %%
type(mylist)
# Out:
# list

# %% [markdown]
# Guardar valores en la lista anterior usando "append()" e imprimirlo por pantalla

# %%
mylist.append('perez') #para ello tenemos que nombrar la lista que queremos que se añada si no dara error
print(mylist)
# Out:
# [1, 2, 4, 'pepe', 'mundo', 'perez']

# %% [markdown]
# Guardar valores en la siguiente lista usando "insert()" e imprimirlo por pantalla

# %%
mylist.insert(3,"data")
print(mylist)
# Out:
# [1, 2, 4, 'data', 'pepe', 'mundo', 'perez']
