# %%
# "Ejercicio 1" Sentencias de if, else, elseif
can_fly =  bool(input("Can fly?") ) 
is_human = bool(input("Is human?") )
has_mask = bool(input("Has mask?") )

#al meter los operadores booleanos podemos automatizarlo de tal forma que parezca un cuestionario


if can_fly == True:
  print("Is human?");
  if is_human == True:
    print("Has mask?");
    if has_mask == True:
      print("Ironman");
    else: 
      print("Captain Marvel");
  elif is_human == False:
    print("Has mask?");
    if has_mask == True:
      print("Ronan Accuser");
    else:
      print("Vision");
else:
  print("Is human?");
  if is_human == True: 
    print("Has mask?");
    if has_mask == True:
      print("Spiderman");
    else:
      print("Hulk");
  elif is_human == False:
    print("Has mask?");
    if has_mask == True:
      print("Black Bolt");
    else:
      print("Thanos");
# Out:
# Can fly?True
# Is human?False
# Has mask?True
# Is human?
# Has mask?
# Ironman

# %% [markdown]
# #Ejercicio nº 2

# %%
year = 2020
bisiesto = 4 / year;
bisiesto2 = year /400

if bisiesto == True:
  print("Este año es bisiesto");
elif bisiesto2 == True:
  print("Este año es bisiesto");
else:
 print("Este año no lo es!!");
# Out:
# Este año no lo es!!

# %% [markdown]
# Ejercicio nº 3

# %%
#input:
sentence = 'Ella te da detalle'
palindromo = sentence[::-1];

#1. Quitar espacios en blanco
junto = palindromo.replace(" ", "");

#2. Poner todo en el mismo formato, ya sea mayusculas o minusculas
junto.lower()




#para hacerlo 
sentence = 'Ella te da detalle'.replace (" ", "").lower()

if sentence ** sentence[::-1]:
  print ("Es palindromo")
else
  print ("No es palidromo")
# Out:
#   File "<ipython-input-81-859f8e95852d>", line 19
#     else
#         ^
# SyntaxError: invalid syntax

# %%
sentence.replace(" ","")
# Out:
# 'Ellatedadetalle'

# %%
sentence.lower()
# Out:
# 'ella te da detalle'
